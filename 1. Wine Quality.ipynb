# %%
import pandas as pd
import pandas_profiling
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score#, cross_val_score
from sklearn.model_selection import cross_val_score

# %%
wine = pd.read_csv('D:/DS/analytics_edge/2. Linear Regression/wine.csv')
wine_test = pd.read_csv('D:/DS/analytics_edge/2. Linear Regression/wine_test.csv')

# %%
pandas_profiling.ProfileReport(wine)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
wine_test.head()
# Out:
#    Year   Price  WinterRain     AGST  HarvestRain  Age  FrancePop
# 0  1979  6.9541         717  16.1667          122    4  54835.832
# 1  1980  6.4979         578  16.0000           74    3  55110.236

# %%
X = pd.DataFrame(wine.Price)
y1 = pd.DataFrame(wine.AGST)
y1.shape
# Out:
# (25, 1)

# %%
lm = linear_model.LinearRegression()

# %%
reg1 = lm.fit(X, y1)
reg1.score(X, y1)
# Out:
# 0.4350231677999201

# %%
y2 = pd.DataFrame(wine.HarvestRain)

# %%
y2.head()
# Out:
#    HarvestRain
# 0          160
# 1           80
# 2          130
# 3          110
# 4          187

# %%
y2['AGST'] = wine['AGST']

# %%
y2.head()
# Out:
#    HarvestRain     AGST
# 0          160  17.1167
# 1           80  16.7333
# 2          130  17.1500
# 3          110  16.1333
# 4          187  16.4167

# %%
reg2 = lm.fit(X, y2)
reg2.score(X, y2)
# Out:
# 0.31734125989495204

# %%
import sklearn
sorted(sklearn.metrics.SCORERS.keys())
# Out:
# ['accuracy',
#  'adjusted_mutual_info_score',
#  'adjusted_rand_score',
#  'average_precision',
#  'balanced_accuracy',
#  'brier_score_loss',
#  'completeness_score',
#  'explained_variance',
#  'f1',
#  'f1_macro',
#  'f1_micro',
#  'f1_samples',
#  'f1_weighted',
#  'fowlkes_mallows_score',
#  'homogeneity_score',
#  'mutual_info_score',
#  'neg_log_loss',
#  'neg_mean_absolute_error',
#  'neg_mean_squared_error',
#  'neg_mean_squared_log_error',
#  'neg_median_absolute_error',
#  'normalized_mutual_info_score',
#  'precision',
#  'precision_macro',
#  'precision_micro',
#  'precision_samples',
#  'precision_weighted',
#  'r2',
#  'recall',
#  'recall_macro',
#  'recall_micro',
#  'recall_samples',
#  'recall_weighted',
#  'roc_auc',
#  'v_measure_score']

# %%
scores = cross_val_score(reg1, X, y1, cv=10, scoring = 'neg_mean_squared_error') 
scores.mean()
# Out:
# -0.32881400778186515

# %%
scores = cross_val_score(reg1, X, y1, cv=10, scoring = 'r2')
scores.mean()
# Out:
# -9.931606140257959

# %%
scores = cross_val_score(reg2, X, y2, cv=10, scoring = 'neg_mean_squared_error')
scores.mean()
# Out:
# -2261.036716169228

# %%
scores = cross_val_score(reg2, X, y2, cv=10, scoring = 'r2')
scores.mean()
# Out:
# -7.365014332281649

# %%
y3= pd.DataFrame(wine['WinterRain'])

# %%
y3['AGST'] = wine['AGST']
y3['Age'] = wine['Age']
y3['HarvestRain'] = wine['HarvestRain']
y3['FrancePop'] = wine['FrancePop']

# %%
y3.head()
# Out:
#    WinterRain     AGST  Age  HarvestRain  FrancePop
# 0         600  17.1167   31          160  43183.569
# 1         690  16.7333   30           80  43495.030
# 2         502  17.1500   28          130  44217.857
# 3         420  16.1333   26          110  45152.252
# 4         582  16.4167   25          187  45653.805

# %%
reg3 = lm.fit(X, y3)
reg3.score(X, y3)
# Out:
# 0.21774150209083265

# %%
scores = cross_val_score(reg3, X, y3, cv=10, scoring = 'neg_mean_squared_error')
scores.mean()
# Out:
# -2698282.2695399025

# %%
scores = cross_val_score(reg3, X, y3, cv=10, scoring = 'r2')
scores.mean()
# Out:
# -138.12180195432467

# %%
from sklearn.feature_selection import SelectKBest, chi2

# %%
wine.head()
# Out:
#    Year   Price  WinterRain     AGST  HarvestRain  Age  FrancePop
# 0  1952  7.4950         600  17.1167          160   31  43183.569
# 1  1953  8.0393         690  16.7333           80   30  43495.030
# 2  1955  7.6858         502  17.1500          130   28  44217.857
# 3  1957  6.9845         420  16.1333          110   26  45152.252
# 4  1958  6.7772         582  16.4167          187   25  45653.805

# %%
# to find the best two feature vectors accoding to the chi squared test.
wine_new = SelectKBest(chi2, k = 3).fit_transform(X, y1)
