# %% [markdown]
# # Perform EDA on the Chicago Grand Theft Auto dataset
# To understand motor vehicle thefts in the city.

# %%
# %matplotlib inline
import pandas as pd
import pandas_profiling
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Loading the Data

# %%
df = pd.read_csv('D:/DS/analytics_edge/chicago_gta.csv', low_memory = False)

# %%
df.shape
# Out:
# (191641, 11)

# %%
df.head()
# Out:
#         ID            Date            LocationDescription  Arrest  Domestic  \
# 0  8951354  12/31/12 23:15                         STREET   False     False
# 1  8951141  12/31/12 22:00                         STREET   False     False
# 2  8952745  12/31/12 22:00  RESIDENTIAL YARD (FRONT/BACK)   False     False
# 3  8952223  12/31/12 22:00                         STREET   False     False
# 4  8951608  12/31/12 21:30                         STREET   False     False
#
#    Beat District CommunityArea  Year   Latitude  Longitude
# 0   623        6            69  2012  41.756284 -87.621645
# 1  1213       12            24  2012  41.898788 -87.661303
# 2  1622       16            11  2012  41.969186 -87.767670
# 3   724        7            67  2012  41.769329 -87.657726
# 4   211        2            35  2012  41.837568 -87.621761

# %%
pandas_profiling.ProfileReport(df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>11 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>191641 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>3.4% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>13.5 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>74.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>4 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>4 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_CommunityArea"><code>CommunityArea</code></a> has 24603 / 12.8% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_CommunityArea"><code>CommunityArea</code></a> has a high cardinality: 80 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Date"><code>Date</code></a> has a high cardinality: 131680 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_District"><code>District</code></a> has 43052 / 22.5% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_Latitude"><code>Latitude</code></a> has 2276 / 1.2% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_LocationDescription"><code>LocationDescription</code></a> has a high cardinality: 78 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Longitude"><code>Longitude</code></a> has 2276 / 1.2% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_Year"><code>Year</code></a> is highly correlated with <a href="#pp_var_ID"><code>ID</code></a> (ρ = 0.99561) <span class="label label-primar

# %%
df['ID'].idxmax()
# Out:
# 18133

# %%
df.loc[df.index == 18133]
# Out:
#             ID           Date LocationDescription  Arrest  Domestic  Beat  \
# 18133  9181151  9/22/11 17:00              STREET   False     False  2232
#
#       District CommunityArea  Year  Latitude  Longitude
# 18133      NaN            73  2011       NaN        NaN

# %%
df['Beat'].min()
# Out:
# 111

# %%
#number of crimes in which an arrest was made
df.loc[df['Arrest'] == True].count()
# Out:
# ID                     15536
# Date                   15536
# LocationDescription    15536
# Arrest                 15536
# Domestic               15536
# Beat                   15536
# District               10886
# CommunityArea          12810
# Year                   15536
# Latitude               15354
# Longitude              15354
# dtype: int64

# %%
#instances where the crime took place in an alley
df.loc[df['LocationDescription'] == 'ALLEY'].count()
# Out:
# ID                     2308
# Date                   2308
# LocationDescription    2308
# Arrest                 2308
# Domestic               2308
# Beat                   2308
# District               1688
# CommunityArea          1980
# Year                   2308
# Latitude               2285
# Longitude              2285
# dtype: int64

# %% [markdown]
# #### Manipulating Dates

# %%
df['Date'].dtype
# Out:
# dtype('O')

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['Date'].head()
# Out:
# 0   2012-12-31 23:15:00
# 1   2012-12-31 22:00:00
# 2   2012-12-31 22:00:00
# 3   2012-12-31 22:00:00
# 4   2012-12-31 21:30:00
# Name: Date, dtype: datetime64[ns]

# %% [markdown]
# Finding the median date for the given dataset

# %%
dates = df['Date'].tolist()
print(len(dates)//2)
# Out:
# 95820

# %%
df.Date[95850]
# Out:
# Timestamp('2006-05-20 21:00:00')

# %% [markdown]
# Extract month and day from Date column and add to separate column.

# %%
import datetime as dt
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.strftime('%a')

# %%
df.head()
# Out:
#         ID                Date            LocationDescription  Arrest  \
# 0  8951354 2012-12-31 23:15:00                         STREET   False
# 1  8951141 2012-12-31 22:00:00                         STREET   False
# 2  8952745 2012-12-31 22:00:00  RESIDENTIAL YARD (FRONT/BACK)   False
# 3  8952223 2012-12-31 22:00:00                         STREET   False
# 4  8951608 2012-12-31 21:30:00                         STREET   False
#
#    Domestic  Beat District CommunityArea  Year   Latitude  Longitude  Month  \
# 0     False   623        6            69  2012  41.756284 -87.621645     12
# 1     False  1213       12            24  2012  41.898788 -87.661303     12
# 2     False  1622       16            11  2012  41.969186 -87.767670     12
# 3     False   724        7            67  2012  41.769329 -87.657726     12
# 4     False   211        2            35  2012  41.837568 -87.621761     12
#
#    Day
# 0  Mon
# 1  Mon
# 2  Mon
# 3  Mon
# 4  Mon

# %%
df.Month.value_counts()
# Out:
# 10    17086
# 7     16801
# 8     16572
# 12    16426
# 11    16063
# 9     16060
# 1     16047
# 5     16035
# 6     16002
# 3     15758
# 4     15280
# 2     13511
# Name: Month, dtype: int64

# %% [markdown]
# The above is sorted is descending order. Month 2 has the least number of observations. Hence, February has the lowest occurences of GTA and October has the most.

# %%
df.Day.value_counts()
# Out:
# Fri    29284
# Wed    27416
# Mon    27397
# Thu    27319
# Sat    27118
# Tue    26791
# Sun    26316
# Name: Day, dtype: int64

# %% [markdown]
# Hence, Friday sees the most crime commited and Sunday sees the least.

# %%
df.Year.value_counts()
# Out:
# 2001    20669
# 2002    18753
# 2004    16862
# 2003    16657
# 2005    16484
# 2006    16098
# 2011    15637
# 2010    15497
# 2008    14445
# 2007    14280
# 2012    14092
# 2009    12167
# Name: Year, dtype: int64

# %% [markdown]
# Most crimes occured in 2001, least in 2009.

# %% [markdown]
# Classifying months with instances of arrests.

# %%
df.loc[df['Arrest'] == True].Month.value_counts()
# Out:
# 1     1435
# 12    1397
# 10    1342
# 8     1329
# 7     1324
# 3     1298
# 11    1256
# 4     1252
# 9     1248
# 2     1238
# 6     1230
# 5     1187
# Name: Month, dtype: int64

# %% [markdown]
# Most arrests: January, Least arrests: May

# %%
df.loc[df['Arrest'] == True].Day.value_counts()
# Out:
# Fri    2370
# Sun    2330
# Sat    2255
# Wed    2210
# Mon    2176
# Tue    2108
# Thu    2087
# Name: Day, dtype: int64

# %% [markdown]
# Most arrests: Friday, Least arrests: Thursday

# %% [markdown]
# #### Visualizing crime trends

# %%
sns.distplot(df['Year'], bins = 50)

# %%
sns.kdeplot(df['Year'], shade = True)

# %% [markdown]
# Crimes decrease from 2002 to 2009, and then rise back up through 2012.

# %%
sns.boxplot(df.loc[df['Arrest'] == True].Year)

# %% [markdown]
# Since range of the data is from 2002 to 2012, the middle of the time period is the beginning of 2007. It looks like there were more crimes for which arrests were made in the first half of the time period or the second half of the time period.

# %%
arrest_year = pd.crosstab(index = df['Year'], columns = df['Arrest'])
arrest_year
# Out:
# Arrest  False  True
# Year
# 2001    18517   2152
# 2002    16638   2115
# 2003    14859   1798
# 2004    15169   1693
# 2005    14956   1528
# 2006    14796   1302
# 2007    13068   1212
# 2008    13425   1020
# 2009    11327    840
# 2010    14796    701
# 2011    15012    625
# 2012    13542    550

# %% [markdown]
# For 2001, Arrested = 2152, not Arrested = 18517.
# Therefore, the fraction of motor vehicle thefts in 2001 for which an arrest was made is thus 2152/(2152+18517) = 0.1041173.

# %% [markdown]
# For 2007 has 1212 observations with Arrest=TRUE and 13068 observations with Arrest=FALSE. The fraction of motor vehicle thefts in 2007 for which an arrest was made is thus 1212/(1212+13068) = 0.08487395.

# %% [markdown]
# 2012 has 550 observations with Arrest=TRUE and 13542 observations with Arrest=FALSE. The fraction of motor vehicle thefts in 2012 for which an arrest was made is thus 550/(550+13542) = 0.03902924.

# %%
df.LocationDescription.value_counts()
# Out:
# STREET                                             156564
# PARKING LOT/GARAGE(NON.RESID.)                      14852
# OTHER                                                4573
# ALLEY                                                2308
# GAS STATION                                          2111
# DRIVEWAY - RESIDENTIAL                               1675
# RESIDENTIAL YARD (FRONT/BACK)                        1536
# RESIDENCE                                            1302
# RESIDENCE-GARAGE                                     1176
# VACANT LOT/LAND                                       985
# VEHICLE NON-COMMERCIAL                                817
# SIDEWALK                                              462
# CHA PARKING LOT/GROUNDS                               405
# AIRPORT/AIRCRAFT                                      363
# POLICE FACILITY/VEH PARKING LOT                       266
# PARK PROPERTY                                         255
# SCHOOL, PUBLIC, GROUNDS                               206
# APARTMENT                                             184
# SPORTS ARENA/STADIUM                                  166
# CTA GARAGE / OTHER PROPERTY                           148
# COMMERCIAL / BUSINESS OFFICE                          126
# HOTEL/MOTEL                                           124
# SCHOOL, PUBLIC, BUILDING                              114
# HOSPITAL BUILDING/GROUNDS                             101
# GROCERY FOOD STORE                                     80
# CHURCH/SYNAGOGUE/PLACE OF WORSHIP                      56
# RESTAURANT                                             49
# GOVERNMENT BUILDING/PROPERTY                           48
# COLLEGE/UNIVERSITY GROUNDS                             47
# CAR WASH                                               44
#                                                     ...
# AIRPORT VENDING ESTABLISHMENT                          10
# ATHLETIC CLUB                                           9
# OTHER COMMERCIAL TRANSPORTATION                         8
# DRUG STORE                                              8
# CONVENIENCE STORE                                       7
# BANK                                                    7
# FOREST PRESERVE                                         6
# CHA APARTMENT                                           5
# DAY CARE CENTER                                         5
# FIRE STATION                                            5
# AIRPORT TERMINAL UPPER LEVEL - NON-SECURE AREA          5
# LAKEFRONT/WATERFRONT/RIVERBANK                          4
# AIRPORT BUILDING NON-TERMINAL - NON-SECURE AREA         4
# SAVINGS AND LOAN                                        4
# BARBERSHOP                                              4
# ABANDONED BUILDING                                      4
# LIBRARY                                                 4
# BOWLING ALLEY                                           3
# MEDICAL/DENTAL OFFICE                                   3
# CLEANING STORE                                          3
# COLLEGE/UNIVERSITY RESIDENCE HALL                       2
# BRIDGE                                                  2
# CURRENCY EXCHANGE                                       2
# CTA TRAIN                                               1
# AIRPORT BUILDING NON-TERMINAL - SECURE AREA             1
# JAIL / LOCK-UP FACILITY                                 1
# AIRPORT EXTERIOR - SECURE AREA                          1
# NEWSSTAND                                               1
# APPLIANCE STORE                                         1
# ANIMAL HOSPITAL                                         1
# Name: LocationDescription, Length: 78, dtype: int64

# %%
options = ['STREET', 'PARKING LOT/GARAGE(NON.RESID.)', 'ALLEY', 'GAS STATION', 'DRIVEWAY - RESIDENTIAL']

# %%
top5 = df.loc[df['LocationDescription'].isin(options)]

# %%
top5.sample(5)
# Out:
#              ID                Date             LocationDescription  Arrest  \
# 101096  4553012 2006-01-23 21:30:00                          STREET   False
# 114442  3909131 2005-04-09 14:00:00                          STREET   False
# 148264  2665599 2003-04-04 17:06:00  PARKING LOT/GARAGE(NON.RESID.)    True
# 492     8938848 2012-12-19 19:20:00                          STREET   False
# 163117  2163835 2002-06-03 02:00:00                          STREET   False
#
#         Domestic  Beat District CommunityArea  Year   Latitude  Longitude  \
# 101096     False   321        3            42  2006  41.773334 -87.597140
# 114442     False   412        4            48  2005  41.734187 -87.586713
# 148264     False  2532       25            25  2003  41.909496 -87.764876
# 492        False  2522       25            19  2012  41.923199 -87.748075
# 163117     False  1023      NaN            29  2002  41.864789 -87.695714
#
#         Month  Day
# 101096      1  Mon
# 114442      4  Sat
# 148264      4  Fri
# 492        12  Wed
# 163117      6  Mon

# %%
top5.shape
# Out:
# (177510, 13)

# %% [markdown]
# Number of observations within the top 5 areas for crime is 177510.

# %%
arrest_top5 = pd.crosstab(index = top5['LocationDescription'], columns = top5['Arrest'])
arrest_top5.head()
# Out:
# Arrest                           False  True
# LocationDescription
# ALLEY                             2059    249
# DRIVEWAY - RESIDENTIAL            1543    132
# GAS STATION                       1672    439
# PARKING LOT/GARAGE(NON.RESID.)   13249   1603
# STREET                          144969  11595

# %% [markdown]
# Inferring from the above daaframe, gas station has the highest arrest rate.

# %%
top5.loc[top5['LocationDescription'] == 'GAS STATION'].Day.value_counts()
# Out:
# Sat    338
# Sun    336
# Fri    332
# Thu    282
# Mon    280
# Wed    273
# Tue    270
# Name: Day, dtype: int64

# %% [markdown]
# Most motor theft happens on saturday at gas stations.

# %%
top5.loc[top5['LocationDescription'] == 'DRIVEWAY - RESIDENTIAL'].Day.value_counts()
# Out:
# Thu    263
# Fri    257
# Mon    255
# Tue    243
# Wed    234
# Sun    221
# Sat    202
# Name: Day, dtype: int64

# %% [markdown]
# Fewest motor vehicle theft also happens  on saturdays at residential driveways.
